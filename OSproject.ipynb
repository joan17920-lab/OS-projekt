# %%
import pandas as pd
import os
import plotly.express as px
# Läs in data
path = os.path.join(os.getcwd(),"data","athlete_events.csv")
os_data = pd.read_csv(path)
# Checka grund data
os_data.info()
print(f"Totalt är {os_data['NOC'].nunique()} länder med i datan, de är {os_data['NOC'].unique()}")
print(f"Totalt har {os_data['Sport'].nunique()} sport, de är {os_data['Sport'].unique()}")
print(f"Medaljtyper är {os_data['Medal'].unique()}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB
# Totalt är 230 länder med i datan, de är ['CHN' 'DEN' 'NED' 'USA' 'FIN' 'NOR' 'ROU' 'EST' 'FRA' 'MAR' 'ESP' 'EGY'
#  'IRI' 'BUL' 'ITA' 'CHA' 'AZE' 'SUD' 'RUS' 'ARG' 'CUB' 'BLR' 'GRE' 'CMR'
#  'TUR' 'CHI' 'MEX' 'URS' 'NCA' 'HUN' 'NGR' 'ALG' 'KUW' 'BRN' 'PAK' 'IRQ'
#  'UAR' 'LIB' 'QAT' 'MAS' 'GER' 'CAN' 'IRL' 'AUS' 'RSA' 'ERI' 'TAN' 'JOR'
#  'TUN' 'LBA' 'BEL' 'DJI' 'PLE' 'COM' 'KAZ' 'BRU' 'IND' 'KSA' 'SYR' 'MDV'
#  'ETH' 'UAE' 'YAR' 'INA' 'PHI' 'SGP' 'UZB' 'KGZ' 'TJK' 'EUN' 'JPN' 'CGO'
#  'SUI' 'BRA' 'FRG' 'GDR' 'MON' 'ISR' 'URU' 'SWE' 'ISV' 'SRI' 'ARM' 'CIV'
#  'KEN' 'BEN' 'UKR' 'GBR' 'GHA' 'SOM' 'LAT' 'NIG' 'MLI' 'AFG' 'POL' 'CRC'
#  'PAN' 'GEO' 'SLO' 'CRO' 'GUY' 'NZL' 'POR' 'PAR' 'ANG' 'VEN' 'COL' 'BAN'
#  'PER' 'ESA' 'PUR' 'UGA' 'HON' 'ECU' 'TKM' 'MRI' 'SEY' 'TCH' 'LUX' 'MTN'
#  'CZE' 'SKN' 'TTO' 'DOM' 'VIN' 'JAM' 'LBR' 'SUR' 'NEP' 'MGL' 'AUT' 'PLW'
#  'LTU' 'TOG' 'NAM' 'AHO' 'ISL' 'ASA' 'SAM' 'RWA' 'DMA' 'HAI' 'MLT' 'CYP'
#  'GUI' 'BIZ' 'YMD' 'KOR' 'THA' 'BER' 'ANZ' 'SCG' 'SLE' 'PNG' 'YEM' 'IOA'
#  'OMA' 'FIJ' 'VAN' 'MDA' 'YUG' 'BAH' 'GUA' 'SRB' 'IVB' 'MOZ' 'CAF' 'MAD'
#  'MAL' 'BIH' 'GUM' 'CAY' 'SVK' 'BAR' 'GBS' 'TLS' 'COD' 'GAB' 'SMR' 'LAO'
#  'BOT' 'ROT' 'CAM' 'PRK' 'SOL' 'SEN' 'CPV' 'CRT' 'GEQ' 'BOL' 'SAA' 'AND'
#  'ANT' 'ZIM' 'GRN' 'HKG' 'LCA' 'FSM' 'MYA' 'MAW' 'ZAM' 'RHO' 'TPE' 'STP'
#  'MKD' 'BOH' 'TGA' 'LIE' 'MNE' 'GAM' 'COK' 'ALB' 'WIF' 'SWZ' 'BUR' 'NBO'
#  'BDI' 'ARU' 'NRU' 'VNM' 'VIE' 'BHU' 'MHL' 'KIR' 'UNK' 'TUV' 'NFL' 'KOS'
#  'SSD' 'LES']
# Totalt har 66 sport, de är ['Basketball' 'Judo' 'Football' 'Tug-Of-War' 'Speed Skating'
#  'Cross Country Skiing' 'Athletics' 'Ice Hockey' 'Swimming' 'Badminton'
#  'Sailing' 'Biathlon' 'Gymnastics' 'Art Competitions' 'Alpine Skiing'
#  'Handball' 'Weightlifting' 'Wrestling' 'Luge' 'Water Polo' 'Hockey'
#  'Rowing' 'Bobsleigh' 'Fencing' 'Equestrianism' 'Shooting' 'Boxing'
#  'Taekwondo' 'Cycling' 'Diving' 'Canoeing' 'Tennis' 'Modern Pentathlon'
#  'Figure Skating' 'Golf' 'Softball' 'Archery' 'Volleyball'
#  'Synchronized Swimming' 'Table Tennis' 'Nordic Combined' 'Baseball'
#  'Rhythmic Gymnastics' 'Freestyle Skiing' 'Rugby Sevens' 'Trampolining'
#  'Beach Volleyball' 'Triathlon' 'Ski Jumping' 'Curling' 'Snowboarding'
#  'Rugby' 'Short Track Speed Skating' 'Skeleton' 'Lacrosse' 'Polo'
#  'Cricket' 'Racquets' 'Motorboating' 'Military Ski Patrol' 'Croquet'
#  'Jeu De Paume' 'Roque' 'Alpinism' 'Basque Pelota' 'Aeronautics']
# Medaljtyper är [nan 'Gold' 'Bronze' 'Silver']

# %%
#Statistik för ålden
os_data['Age'].describe()
# Out:
# count    261642.000000
# mean         25.556898
# std           6.393561
# min          10.000000
# 25%          21.000000
# 50%          24.000000
# 75%          28.000000
# max          97.000000
# Name: Age, dtype: float64

# %%
# Checka null värde
nulls = os_data.isnull().sum()
nulls
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# dtype: int64

# %%
# Diagram över könsfördelningen
os_gender = os_data.groupby(["Year","Sex"]).size().reset_index(name = "Count")
fig = px.bar(os_gender, x = "Year", y="Count",color= "Sex", title="Gender distribution")
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="efb40f0a-2586-487b-b94c-c12ca6dfee3f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("efb40f0a-2586-487b-b94c-c12ca6dfee3f")) {                    Plotly.newPlot(                        "efb40f0a-2586-487b-b94c-c12ca6dfee3f",                        [{"hovertemplate":"Sex=M\u003cbr\u003eYear=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"M","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"M","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"i2","bdata":"aAdsB3AHcgd0B3gHgAeEB4gHjAeQB5wHoAekB6gHrAewB7QHuAe8B8AHxAfIB8oHzAfOB9AH0gfUB9YH2AfaB9wH3gfgBw=="},"xaxis":"x","y":{"dtype":"i2","bdata":"fAFvBwUFugbuC3EPPhA4FREUiAvEGj8a\u002fB2vFFEdMB5eIIck2B5fGp0h1SjjKwcIRCKtCMYg3wnZHkEKah77CcEbNAspHQ=="},"yaxis":"y","type":"bar"},{"hovertemplate":"Sex=F\u003cbr\u003eYear=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"F","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"F","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"i2","bdata":"bAdwB3IHdAd4B4AHhAeIB4wHkAecB6AHpAeoB6wHsAe0B7gHvAfAB8QHyAfKB8wHzgfQB9IH1AfWB9gH2gfcB94H4Ac="},"xaxis":"x","y":{"dtype":"i2","bdata":"IQAQAAsALwBXAIYABQG1AXEBJQL5ApIGcwTCBtgGkQgwCi4KiginC38QOhRRBJATaAU3FS4GqhXdBrgWNwe3FucHTxg="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"f ...

# %%
# Diagram över topp 10 länder som tagit flest medaljer
os_topp10 = os_data[["Team","Medal"]].groupby("Team")["Medal"].count().sort_values(ascending=False).head(10).reset_index()
os_topp10
px.bar(os_topp10, x="Medal", y="Team",color = "Team",title="Topp 10 country")
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="8e04ae96-5385-49e8-ae55-07a8dc8964fb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("8e04ae96-5385-49e8-ae55-07a8dc8964fb")) {                    Plotly.newPlot(                        "8e04ae96-5385-49e8-ae55-07a8dc8964fb",                        [{"hovertemplate":"Team=%{y}\u003cbr\u003eMedal=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"United States","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"United States","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"i2","bdata":"YxQ="},"xaxis":"x","y":["United States"],"yaxis":"y","type":"bar"},{"hovertemplate":"Team=%{y}\u003cbr\u003eMedal=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Soviet Union","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Soviet Union","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"i2","bdata":"kwk="},"xaxis":"x","y":["Soviet Union"],"yaxis":"y","type":"bar"},{"hovertemplate":"Team=%{y}\u003cbr\u003eMedal=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Germany","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Germany","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"i2","bdata":"wAc="},"xaxis":"x","y":["Germany"],"yaxis":"y","type":"bar"},{"hovertemplate":"Team=%{y}\u003cbr\u003eMedal=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Great Britain","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Great Britain","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"i2","bdata":"iQY="},"xaxis":"x","y":["Great Britain"],"yaxis":"y","type":"bar"},{"hovertemplate":"Team=%{y}\u003cbr\u003eMedal=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"France","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"France","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"i2","bdata":"DgY="},"xaxis":"x","y":["France"],"yaxis":"y","type":"bar"},{"hovertemplate":"Team=%{y}\u003cbr\u003eMedal=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Italy","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Italy","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"i2","bdata":"9wU="},"xaxis":"x","y":["Italy"],"yaxis":"y","type":"bar"},{"hovertemplate":"Team=%{y}\u003cbr\u003eMedal=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sweden","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Sweden","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"i2","bdata":"mgU="},"xaxis":"x","y":["Sweden"],"yaxis":"y","type":"bar"},{"hovertemplate":"Team=%{y}\u003cbr\u003eMedal=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Australia","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Australia","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"i2","bdata":"GgU="},"xaxis":"x","y":["Australia"],"yaxis":"y","type":"bar"},{"hovertemplate":"Team=%{y}\u003cbr\u003eMedal=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Canada","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Canada","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"i2","bdata":"2wQ="},"xaxis":"x","y":["Canada"],"yaxis":"y","type":"bar"},{"hovertemplate":"Team=%{y}\u003cbr\u003eMedal=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Hungary","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"Hungary","orientation":"h","showlegend":true ...

# %%
#  anonymisera  idrottarnas namn med hashfunktionen SHA-256
import hashlib
os_data["Name_hash"]=os_data["Name"].apply(lambda x: hashlib.sha256(x.encode()).hexdigest())
os_hash_name = os_data.drop(columns="Name")
os_hash_name.head()
# Out:
#    ID Sex   Age  Height  Weight            Team  NOC        Games  Year  \
# 0   1   M  24.0   180.0    80.0           China  CHN  1992 Summer  1992
# 1   2   M  23.0   170.0    60.0           China  CHN  2012 Summer  2012
# 2   3   M  24.0     NaN     NaN         Denmark  DEN  1920 Summer  1920
# 3   4   M  34.0     NaN     NaN  Denmark/Sweden  DEN  1900 Summer  1900
# 4   5   F  21.0   185.0    82.0     Netherlands  NED  1988 Winter  1988
#
#    Season       City          Sport                             Event Medal  \
# 0  Summer  Barcelona     Basketball       Basketball Men's Basketball   NaN
# 1  Summer     London           Judo      Judo Men's Extra-Lightweight   NaN
# 2  Summer  Antwerpen       Football           Football Men's Football   NaN
# 3  Summer      Paris     Tug-Of-War       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Winter    Calgary  Speed Skating  Speed Skating Women's 500 metres   NaN
#
#                                            Name_hash
# 0  3a4eef48434c66b3f14ab0221f6762d0ef7c6135ab2790...
# 1  a6430cc6630934275dc6283f7e97e9625e6587cdddec7a...
# 2  9c198b205332c2c8e1542e0f9534b9e270780a41d978ec...
# 3  0a477bb1c5ad39716f9c775e54d18d16aa8b37ada55548...
# 4  5b7be356aa28178096dc6747f0b8e4e393eaceb5f95310...

# %%
# Tvätta data för Östrike 
os_Austria = os_hash_name[os_hash_name["Team"]=="Austria"]
os_Austria.head(2)
# Out:
#        ID Sex   Age  Height  Weight     Team  NOC        Games  Year  Season  \
# 1738  968   F  16.0     NaN     NaN  Austria  AUT  1912 Summer  1912  Summer
# 1739  968   F  16.0     NaN     NaN  Austria  AUT  1912 Summer  1912  Summer
#
#            City     Sport                                            Event  \
# 1738  Stockholm  Swimming            Swimming Women's 100 metres Freestyle
# 1739  Stockholm  Swimming  Swimming Women's 4 x 100 metres Freestyle Relay
#
#        Medal                                          Name_hash
# 1738     NaN  75ced3fe1cd3e805cbabb3a33e16c4c06f52fc0d562f67...
# 1739  Bronze  75ced3fe1cd3e805cbabb3a33e16c4c06f52fc0d562f67...
